# %% [markdown]
# # How to pull in reusable code from source control
#
# This notebook demonstrates several different ways to incorporate R code from source control into a notebook.

# %% [markdown]
# ## Setup

# %%
library(devtools)
library(bigrquery)
# Out:
# Loading required package: usethis

# %%
# BigQuery billing project name.
BILLING_PROJECT_ID <- Sys.getenv('GOOGLE_PROJECT')

# %% [markdown]
# # Install a package from GitHub
#
# You can see the GitHub repository here: https://github.com/r-lib/gargle

# %%
# Install a particular version of the code.
devtools::install_github('Gibbsdavidl/CatterPlots', ref = 'ae17cd5e49ddda4ecfe0eba8a4c21df8c88e72c4')
# Out:
# Downloading GitHub repo Gibbsdavidl/CatterPlots@ae17cd5e49ddda4ecfe0eba8a4c21df8c88e72c4
# ✔  checking for file ‘/tmp/RtmpIdIXnM/remotes9ec2bc8ee7/Gibbsdavidl-CatterPlots-ae17cd5/DESCRIPTION’
# ─  preparing ‘CatterPlots’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘CatterPlots_0.0.2.tar.gz’
# Installing package into ‘/home/jupyter-user/notebooks/packages’
# (as ‘lib’ is unspecified)

# %%
# Load the code.
library(CatterPlots)
# Out:
# Welcome to CatterPlots.

# %%
# Use the code.
x <- -10:10
y <- -x^2 + 10
purr <- catplot(xs = (x + 10) * 10, ys = y + 100, cat = 3, catcolor = '#000000FF',
                xlab = 'time (ms)', ylab = 'cat elevation (mm)', main = 'Surprised cat')
# Out:
# Plot with title “Surprised cat”

# %% [markdown]
# Just FYI, similarly we can install Python packages from GitHub like so:
#
# `pip install git+https://github.com/verilylifesciences/analysis-py-utils.git@v0.1.0`

# %% [markdown]
# # Install a package from a Cloud Source Repository
#
# If you have permission to view this repository, you can see the source code for this package here: https://source.cloud.google.com/terra-resources/rterra
#
# For more detail, see https://cloud.google.com/source-repositories/

# %%
# Clone the code repository.
system('gcloud source repos clone rterra --project=terra-resources', intern=TRUE)
# Out:
# character(0)

# %%
# Install the R package.
devtools::install('rterra')
# Out:
# ✔  checking for file ‘/home/jupyter-user/notebooks/Terra Notebooks Playground - deflaux 20210519/edit/rterra/DESCRIPTION’
# ─  preparing ‘rterra’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘rterra_0.1.0.tar.gz’
#
# Running /usr/lib/R/bin/R CMD INSTALL /tmp/RtmpIdIXnM/rterra_0.1.0.tar.gz \
#   --install-tests
# * installing to library ‘/home/jupyter-user/notebooks/packages’
# * installing *source* package ‘rterra’ ...
# ** using staged installation
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (rterra)

# %%
# Load the R package.
library(rterra)

# %%
# Use the R package.
hello()
# Out:
# Hello world!
# You can try out source control by adding more to this message.
# Hello from deflaux 2019-02-11.
# Goodbye!
# [1] "Hello world!"
# [2] "You can try out source control by adding more to this message."
# [3] "Hello from deflaux 2019-02-11."
# [4] "Goodbye!"

# %% [markdown]
# Just FYI, similarly for Python we can install local Python packages via:
#
# `pip install -e <DIRECTORY>`

# %% [markdown]
# # Provenance

# %%
devtools::session_info()
# Out:
# ─ Session info ───────────────────────────────────────────────────────────────
#  setting  value
#  version  R version 4.0.5 (2021-03-31)
#  os       Ubuntu 18.04.5 LTS
#  system   x86_64, linux-gnu
#  ui       X11
#  language (EN)
#  collate  en_US.UTF-8
#  ctype    en_US.UTF-8
#  tz       Etc/UTC
#  date     2021-05-19
#
# ─ Packages ───────────────────────────────────────────────────────────────────
#  package     * version date       lib source
#  assertthat    0.2.1   2019-03-21 [2] CRAN (R 4.0.5)
#  base64enc     0.1-3   2015-07-28 [2] CRAN (R 4.0.5)
#  bigrquery   * 1.3.2   2020-10-05 [2] CRAN (R 4.0.5)
#  bit           4.0.4   2020-08-04 [2] CRAN (R 4.0.5)
#  bit64         4.0.5   2020-08-30 [2] CRAN (R 4.0.5)
#  cachem        1.0.4   2021-02-13 [2] CRAN (R 4.0.5)
#  callr         3.7.0   2021-04-20 [2] CRAN (R 4.0.5)
#  CatterPlots * 0.0.2   2021-05-19 [1] Github (Gibbsdavidl/CatterPlots@ae17cd5)
#  cli           2.5.0   2021-04-26 [2] CRAN (R 4.0.5)
#  crayon        1.4.1   2021-02-08 [2] CRAN (R 4.0.5)
#  curl          4.3.1   2021-04-30 [2] CRAN (R 4.0.5)
#  DBI           1.1.1   2021-01-15 [2] CRAN (R 4.0.5)
#  dbplyr        2.1.1   2021-04-06 [2] CRAN (R 4.0.5)
#  desc          1.3.0   2021-03-05 [2] CRAN (R 4.0.5)
#  devtools    * 2.4.1   2021-05-05 [2] CRAN (R 4.0.5)
#  digest        0.6.27  2020-10-24 [2] CRAN (R 4.0.5)
#  dplyr         1.0.6   2021-05-05 [2] CRAN (R 4.0.5)
#  ellipsis      0.3.2   2021-04-29 [2] CRAN (R 4.0.5)
#  evaluate      0.14    2019-05-28 [2] CRAN (R 4.0.5)
#  fansi         0.4.2   2021-01-15 [2] CRAN (R 4.0.5)
#  fastmap       1.1.0   2021-01-25 [2] CRAN (R 4.0.5)
#  fs            1.5.0   2020-07-31 [2] CRAN (R 4.0.5)
#  generics      0.1.0   2020-10-31 [2] CRAN (R 4.0.5)
#  glue          1.4.2   2020-08-27 [2] CRAN (R 4.0.5)
#  htmltools     0.5.1.1 2021-01-22 [2] CRAN (R 4.0.5)
#  httr          1.4.2   2020-07-20 [2] CRAN (R 4.0.5)
#  IRdisplay     1.0     2021-01-20 [2] CRAN (R 4.0.5)
#  IRkernel      1.1.1   2020-07-20 [2] CRAN (R 4.0.5)
#  jsonlite      1.7.2   2020-12-09 [2] CRAN (R 4.0.5)
#  lifecycle     1.0.0   2021-02-15 [2] CRAN (R 4.0.5)
#  magrittr      2.0.1   2020-11-17 [2] CRAN (R 4.0.5)
#  memoise       2.0.0   2021-01-26 [2] CRAN (R 4.0.5)
#  pbdZMQ        0.3-5   2021-02-10 [2] CRAN (R 4.0.5)
#  pillar        1.6.0   2021-04-13 [2] CRAN (R 4.0.5)
#  pkgbuild      1.2.0   2020-12-15 [2] CRAN (R 4.0.5)
#  pkgconfig     2.0.3   2019-09-22 [2] CRAN (R 4.0.5)
#  pkgload       1.2.1   2021-04-06 [2] CRAN (R 4.0.5)
#  png           0.1-7   2013-12-03 [2] CRAN (R 4.0.5)
#  prettyunits   1.1.1   2020-01-24 [2] CRAN (R 4.0.5)
#  processx      3.5.2   2021-04-30 [2] CRAN (R 4.0.5)
#  ps            1.6.0   2021-02-28 [2] CRAN (R 4.0.5)
#  purrr         0.3.4   2020-04-17 [2] CRAN (R 4.0.5)
#  R6            2.5.0   2020-10-28 [2] CRAN (R 4.0.5)
#  Rcpp          1.0.6   2021-01-15 [2] CRAN (R 4.0.5)
#  remotes       2.3.0   2021-04-01 [2] CRAN (R 4.0.5)
#  repr          1.1.3   2021-01-21 [2] CRAN (R 4.0.5)
#  rlang         0.4.11  2021-04-30 [2] CRAN (R 4.0.5)
#  rprojroot     2.0.2   2020-11-15 [2] CRAN (R 4.0.5)
#  rstudioapi    0.13    2020-11-12 [2] CRAN (R 4.0.5)
#  rterra      * 0.1.0   2021-05-19 [1] local
#  sessioninfo   1.1.1   2018-11-05 [2] CRAN (R 4.0.5)
#  testthat      3.0.2   2021-02-14 [2] CRAN (R 4.0.5)
#  tibble        3.1.1   2021-04-18 [2] CRAN (R 4.0.5)
#  tidyselect    1.1.1   2021-04-30 [2] CRAN (R 4.0.5)
#  usethis     * 2.0.1   2021-02-10 [2] CRAN (R 4.0.5)
#  utf8          1.2.1   2021-03-12 [2] CRAN (R 4.0.5)
#  uuid          0.1-4   2020-02-26 [2] CRAN (R 4.0.5)
#  vctrs         0.3.8   2021-04-29 [2] CRAN (R 4.0.5)
#  withr         2.4.2   2021-04-18 [2] CRAN (R 4.0.5)
#
# [1] /home/jupyter-user/notebooks/packages
# [2] /usr/local/lib/R/site-library
# [3] /usr/lib/R/site-library
# [4] /usr/lib/R/library

# %% [markdown]
# Copyright 2018 The Broad Institute, Inc., Verily Life Sciences, LLC All rights reserved.
#
# This software may be modified and distributed under the terms of the BSD license. See the LICENSE file for details.
